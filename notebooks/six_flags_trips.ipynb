# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
import os
from pathlib import Path

# set cwd to src
os.chdir('../src')
from utils import *

data_path = Path('../data')

# %%
trips_df = pd.read_csv(data_path / 'dest_trips_OKC_Six_Flags_2023-01-01_to_2024-01-30.csv')
polygon_gdf = gpd.read_file(data_path / 'six_flags_polygons.csv')

# %%
display(trips_df)
# Out:
#        year  month  day  hour  minute  second         orig_qk17  \
# 0      2023      1   27    14      20       8  2311212101230110
# 1      2023      1    5    18      16      24  2311212101110311
# 2      2023      1    3    14      27      57  2311210322323210
# 3      2023      1   22    20      31       8  2311212101230133
# 4      2023      1   30    12      26      17  2311212011310300
# ...     ...    ...  ...   ...     ...     ...               ...
# 11288  2023      1   23    13       8      50  2311212101222100
# 11289  2023      1    8    15      11      37  2311123123033100
# 11290  2023      1   23    14      20      39  2311210321232202
# 11291  2023      1   13    14      29      40  2311210322332013
# 11292  2023      1    5    13      18      56  2311210322322000
#
#               dest_qk17  start_lat  start_lon    end_lat    end_lon  count  \
# 0      2311212100110100  35.351936 -97.497913  35.460583 -97.591377      1
# ...
